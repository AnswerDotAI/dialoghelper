# %% [markdown]
# import me

# %% [markdown]
# Dear {{name}},

# %% [markdown]
# Dear {{name}},

# %% [markdown]
# Dear {{name}},

# %% [markdown]
# Dear {{name}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},

# %% [markdown]
# Dear {{name}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},

# %% [markdown]
# Dear {{name}}, {{#section}}

# %% [markdown]
# Dear {{name}}, {{#section}}{{/section}}

# %% [markdown]
# Dear {{name}},{{#section}}{{/section}}

# %% [markdown]
# Dear {{first_name}} {{last_name}},{{#section}}{{/section}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},{{#section}}{{/section}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},{{#section}}{{/section}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},{{#section}}{{/section}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},{{#section}}{{/section}},

# %% [markdown]
# Dear {{first_name}} {{last_name}},{{#section}}{{/section}},

# %% [markdown]
# import me

# %% [markdown]
# import me

# %% [markdown]
# import me

# %% [markdown]
# import me
